# %% [markdown]
# # Task: Goldfish-to-shark adversarial attack
#
# You are given a set of images that are classified by a model trained on Imagenet as a goldfish (class `GOLDFISH_LABEL=1`).<br>
# Your task is to compute a strip of pixels of height 10, which, when pasted into the top 10 rows of *each* of the original images, makes the model classify each image as a shark (class `SHARK_LABEL=2`) with returned probability at least 0.5.
#
# This should run under 2 minutes on CPU.

# %% [markdown]
# ## Data
#
# Below you can find a piece of code that download a zipfile and displays the images.

# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import PIL.Image
import matplotlib.pyplot as plt
import numpy as np
import requests
import torch
import zipfile
from io import BytesIO
from PIL import Image
from torch import Tensor
from torchvision.transforms import v2
from typing import cast

from timm.data.constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD


torch.use_deterministic_algorithms(True)


def get_images(
    url: str = "https://www.mimuw.edu.pl/~cygan/goldfish.zip",
    target_height: int = 100,
    target_width: int = 100,
) -> list[Tensor]:
    """Return five images as tensors of shape (C=3, H=target_height, W=target_width), 0..1 values."""
    request = requests.get(url)
    images = []
    with zipfile.ZipFile(BytesIO(request.content)) as z:
        for filename in z.namelist():
            if not filename.lower().endswith((".jpg", ".jpeg")):
                continue
            with z.open(filename) as f:
                images.append(Image.open(f).convert("RGB"))

    transformations = v2.Compose([
        v2.Resize(size=(target_height, target_width)),
        v2.ToImage(),
        v2.ToDtype(torch.float32, scale=True),  # scale to 0..1
    ])
    return [cast(Tensor, transformations(img)) for img in images]


def tensor_to_pil(image: Tensor) -> PIL.Image.Image:
    """Convert image tensor of shape (C, H, W), values 0..1, to PIL Image."""
    C, H, W = image.shape
    image = image.detach().permute(1, 2, 0).clone()  # to (H, W, C)
    img = PIL.Image.fromarray((image.numpy() * 255).astype(np.uint8))
    return img


normalize_colors = v2.Normalize(
    mean=IMAGENET_DEFAULT_MEAN,
    std=IMAGENET_DEFAULT_STD
)

# %%
images = get_images()
for img in images:
    print(img.shape)
    display(tensor_to_pil(img))
# Out:
# torch.Size([3, 100, 100])
# <PIL.Image.Image image mode=RGB size=100x100>
# torch.Size([3, 100, 100])
# <PIL.Image.Image image mode=RGB size=100x100>
# torch.Size([3, 100, 100])
# <PIL.Image.Image image mode=RGB size=100x100>
# torch.Size([3, 100, 100])
# <PIL.Image.Image image mode=RGB size=100x100>
# torch.Size([3, 100, 100])
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# ## Model
#
# We will be using the `mobilenet_v2` model, trained to do classification on the Imagenet dataset.
# For this task, the model is a black-box: you do not have to know the details of the model's architecture.
# In particular the model's weights should not be changed.

# %%
import torch.nn
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights

DEFAULT_DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

def get_model(device: str = DEFAULT_DEVICE) -> torch.nn.Module:
    """Load a pretrained MobileNetV2 model.

    Input: normalized (not 0..1) images of shape (B, C, H, W),
    Output: logits (not probabilities or logprobs) of shape (B, num_classes=1000,).
    """
    model = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)
    model.to(torch.device(device))
    model.eval()
    model.requires_grad_(False)
    return model

GOLDFISH_LABEL = MobileNet_V2_Weights.IMAGENET1K_V1.meta["categories"].index("goldfish")
SHARK_LABEL = MobileNet_V2_Weights.IMAGENET1K_V1.meta["categories"].index("great white shark")
GOLDFISH_LABEL, SHARK_LABEL
# Out:
# (1, 2)

# %%
model = get_model()
model
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ## Evaluation
#
# Below is a piece of code for:
# * pasting the strip and running model inference on a normalized image;
# * evaluating how well a strip performs, for this attack task.

# %%
STRIP_HEIGHT = 7

def evaluate_strip(model: torch.nn.Module, images: list[Tensor], strip: Tensor, quiet = False) -> float:
    """
    Print goldfish and shark probabilities for each image with the given strip pasted on top.

    Args:
    - model: the classification model.
    - images: list of tensors of shape (3, H, W), values 0..1
    - strip: tensor of shape (3, STRIP_HEIGHT, W), values 0..1.
    """
    C, H, W = images[0].shape
    assert strip.shape == (C, STRIP_HEIGHT, W)
    assert strip.min() >= 0 and strip.max() <= 1, f"Strip should be 0..1, got {strip.min()=}, {strip.max()=}."

    device = next(model.parameters()).device
    p_shark_sum = 0

    for img in images:
        img = img.clone().to(device)
        img[:, :strip.shape[1], :] = strip.to(device)
        img = normalize_colors(img)
        logits = model(img.unsqueeze(0)).squeeze(0)  # Shape (num_classes=1000,)
        probabilities = torch.nn.functional.softmax(logits, dim=-1)
        p_goldfish, p_shark = probabilities[[GOLDFISH_LABEL, SHARK_LABEL]]
        if not quiet:
          print(f'Probabilities assigned to: goldfish={p_goldfish:.5%}, shark={p_shark:.5%}.')
        p_shark_sum += p_shark.item()

    return p_shark_sum


zero_strip = torch.zeros(3, STRIP_HEIGHT, images[0].shape[2])
evaluate_strip(model, images, zero_strip)
# Out:
# Probabilities assigned to: goldfish=99.97601%, shark=0.00000%.
# Probabilities assigned to: goldfish=99.98993%, shark=0.00000%.
# Probabilities assigned to: goldfish=98.48703%, shark=0.00000%.
# Probabilities assigned to: goldfish=94.75501%, shark=0.00000%.
# Probabilities assigned to: goldfish=99.72208%, shark=0.00000%.
# 1.3155995525837919e-11

# %% [markdown]
# ## TO IMPLEMENT
#
# Here you have to implement the function that finds the strip.

# %%
def calculate_strip(model, images, seed: int = 1, quiet: bool = False) -> Tensor:
    device = next(model.parameters()).device
    torch.manual_seed(seed)

    C, H, W = images[0].shape
    B = len(images)

    strip = torch.rand(C, STRIP_HEIGHT, W, device=device, requires_grad=True)

    alpha = 0.01
    num_steps = 4000
    target = torch.full((B,), SHARK_LABEL, dtype=torch.long, device=device)

    for step in range(num_steps):
        batch = []
        for img in images:
            img2 = img.clone().to(device)
            img2[:, :STRIP_HEIGHT, :] = strip
            batch.append(img2)
        batch = torch.stack(batch)
        batch_norm = normalize_colors(batch)

        logits = model(batch_norm)

        loss = torch.nn.functional.cross_entropy(logits, target)

        if strip.grad is not None:
            strip.grad.zero_()
        loss.backward()

        with torch.no_grad():
            grad_sign = strip.grad.sign()
            strip -= alpha * grad_sign
            strip.clamp_(0.0, 1.0)

        if not quiet and (step % 50 == 0 or step == num_steps-1):
            probs = torch.nn.functional.softmax(logits, dim=-1)
            p_shark = probs[:, SHARK_LABEL]
            print(f"step {step}, loss {loss.item():.4f}, min p_shark {p_shark.min().item():.4f}, mean {p_shark.mean().item():.4f}")
            # if (p_shark >= 0.5).all():
            #     print("Warunek osiągnięty, przerywam.")
            #     break

    return strip.detach().cpu()

your_strip = calculate_strip(model, images)
# Out:
# step 0, loss 23.6780, min p_shark 0.0000, mean 0.0000
# step 50, loss 14.4421, min p_shark 0.0000, mean 0.0000
# step 50, loss 14.4421, min p_shark 0.0000, mean 0.0000
# step 100, loss 13.0147, min p_shark 0.0000, mean 0.0000
# step 100, loss 13.0147, min p_shark 0.0000, mean 0.0000
# step 150, loss 12.1440, min p_shark 0.0000, mean 0.0001
# step 150, loss 12.1440, min p_shark 0.0000, mean 0.0001
# step 200, loss 10.7924, min p_shark 0.0000, mean 0.0003
# step 200, loss 10.7924, min p_shark 0.0000, mean 0.0003
# step 250, loss 7.1167, min p_shark 0.0000, mean 0.0050
# step 250, loss 7.1167, min p_shark 0.0000, mean 0.0050
# step 300, loss 5.6203, min p_shark 0.0002, mean 0.0175
# step 300, loss 5.6203, min p_shark 0.0002, mean 0.0175
# step 350, loss 4.7776, min p_shark 0.0004, mean 0.0296
# step 350, loss 4.7776, min p_shark 0.0004, mean 0.0296
# step 400, loss 4.0608, min p_shark 0.0011, mean 0.0436
# step 400, loss 4.0608, min p_shark 0.0011, mean 0.0436
# step 450, loss 3.5480, min p_shark 0.0017, mean 0.0567
# step 450, loss 3.5480, min p_shark 0.0017, mean 0.0567
# step 500, loss 2.9810, min p_shark 0.0048, mean 0.0857
# step 500, loss 2.9810, min p_shark 0.0048, mean 0.0857
# step 550, loss 2.6451, min p_shark 0.0116, mean 0.1012
# step 600, loss 2.2501, min p_shark 0.0180, mean 0.1388
# step 550, loss 2.6451, min p_shark 0.0116, mean 0.1012
# step 600, loss 2.2501, min p_shark 0.0180, mean 0.1388
# step 650, loss 2.0134, min p_shark 0.0286, mean 0.1663
# step 700, loss 1.8214, min p_shark 0.0373, mean 0.1997
# step 650, loss 2.0134, min p_shark 0.0286, mean 0.1663
# step 700, loss 1.8214, min p_shark 0.0373, mean 0.1997
# step 750, loss 1.7068, min p_shark 0.0476, mean 0.2197
# step 800, loss 1.6949, min p_shark 0.0476, mean 0.2228
# step 750, loss 1.7068, min p_shark 0.0476, mean 0.2197
# step 800, loss 1.6949, min p_shark 0.0476, mean 0.2228
# step 850, loss 1.6191, min p_shark 0.0549, mean 0.2355
# step 850, loss 1.6191, min p_shark 0.0549, mean 0.2355
# step 900, loss 1.5388, min p_shark 0.0666, mean 0.2531
# step 950, loss 1.4962, min p_shark 0.0821, mean 0.2571
# step 900, loss 1.5388, min p_shark 0.0666, mean 0.2531
# step 950, loss 1.4962, min p_shark 0.0821, mean 0.2571
# step 1000, loss 1.4339, min p_shark 0.0844, mean 0.2738
# step 1050, loss 1.3840, min p_shark 0.1111, mean 0.2782
# step 1000, loss 1.4339, min p_shark 0.0844, mean 0.2738
# step 1050, loss 1.3840, min p_shark 0.1111, mean 0.2782
# step 1100, loss 1.2880, min p_shark 0.1133, mean 0.3087
# step 1150, loss 1.3066, min p_shark 0.0960, mean 0.3089
# step 1100, loss 1.2880, min p_shark 0.1133, mean 0.3087
# step 1150, loss 1.3066, min p_shark 0.0960, mean 0.3089
# step 1200, loss 1.2837, min p_shark 0.1036, mean 0.3184
# step 1250, loss 1.2653, min p_shark 0.1199, mean 0.3178
# step 1200, loss 1.2837, min p_shark 0.1036, mean 0.3184
# step 1250, loss 1.2653, min p_shark 0.1199, mean 0.3178
# step 1300, loss 1.2095, min p_shark 0.1138, mean 0.3415
# step 1350, loss 1.1838, min p_shark 0.1054, mean 0.3573
# step 1300, loss 1.2095, min p_shark 0.1138, mean 0.3415
# step 1350, loss 1.1838, min p_shark 0.1054, mean 0.3573
# step 1400, loss 1.1462, min p_shark 0.1245, mean 0.3639
# step 1450, loss 1.0892, min p_shark 0.1786, mean 0.3633
# step 1400, loss 1.1462, min p_shark 0.1245, mean 0.3639
# step 1450, loss 1.0892, min p_shark 0.1786, mean 0.3633
# step 1500, loss 1.0741, min p_shark 0.1847, mean 0.3689
# step 1500, loss 1.0741, min p_shark 0.1847, mean 0.3689
# step 1550, loss 1.0660, min p_shark 0.1819, mean 0.3761
# step 1550, loss 1.0660, min p_shark 0.1819, mean 0.3761
# step 1600, loss 1.0342, min p_shark 0.1965, mean 0.3849
# step 1600, loss 1.0342, min p_shark 0.1965, mean 0.3849
# step 1650, loss 1.0423, min p_shark 0.1505, mean 0.3938
# step 1700, loss 0.9895, min p_shark 0.2050, mean 0.3987
# step 1650, loss 1.0423, min p_shark 0.1505, mean 0.3938
# step 1700, loss 0.9895, min p_shark 0.2050, mean 0.3987
# step 1750, loss 0.9917, min p_shark 0.2132, mean 0.3945
# step 1800, loss 0.9746, min p_shark 0.2133, mean 0.4029
# step 1750, loss 0.9917, min p_shark 0.2132, mean 0.3945
# step 1800, loss 0.9746, min p_shark 0.2133, mean 0.4029
# step 1850, loss 0.9603, min p_shark 0.2004, mean 0.4102
# step 1850, loss 0.9603, min p_shark 0.2004, mean 0.4102
# step 1900, loss 0.9689, min p_shark 0.1991, mean 0.4065
# step 1900, loss 0.9689, min p_shark 0.1991, mean 0.4065
# step 1950, loss 0.9545, min p_shark 0.1990, mean 0.4119
# step 1950, loss 0.9545, min p_shark 0.1990, mean 0.4119
# step 2000, loss 0.9415, min p_shark 0.2251, mean 0.4127
# step 2000, loss 0.9415, min p_shark 0.2251, mean 0.4127
# step 2050, loss 0.9152, min p_shark 0.2120, mean 0.4279
# step 2050, loss 0.9152, min p_shark 0.2120, mean 0.4279
# step 2100, loss 0.9398, min p_shark 0.1889, mean 0.4231
# step 2100, loss 0.9398, min p_shark 0.1889, mean 0.4231
# step 2150, loss 0.9012, min p_shark 0.1955, mean 0.4397
# step 2150, loss 0.9012, min p_shark 0.1955, mean 0.4397
# step 2200, loss 0.9312, min p_shark 0.1728, mean 0.4353
# step 2200, loss 0.9312, min p_shark 0.1728, mean 0.4353
# step 2250, loss 0.8698, min p_shark 0.2384, mean 0.4428
# step 2250, loss 0.8698, min p_shark 0.2384, mean 0.4428
# step 2300, loss 0.8648, min p_shark 0.2436, mean 0.4444
# step 2300, loss 0.8648, min p_shark 0.2436, mean 0.4444
# step 2350, loss 0.8631, min p_shark 0.2223, mean 0.4512
# step 2350, loss 0.8631, min p_shark 0.2223, mean 0.4512
# step 2400, loss 0.8389, min p_shark 0.2411, mean 0.4567
# step 2400, loss 0.8389, min p_shark 0.2411, mean 0.4567
# step 2450, loss 0.8362, min p_shark 0.2584, mean 0.4546
# step 2450, loss 0.8362, min p_shark 0.2584, mean 0.4546
# step 2500, loss 0.8415, min p_shark 0.2298, mean 0.4602
# step 2500, loss 0.8415, min p_shark 0.2298, mean 0.4602
# step 2550, loss 0.8524, min p_shark 0.2358, mean 0.4564
# step 2550, loss 0.8524, min p_shark 0.2358, mean 0.4564
# step 2600, loss 0.8501, min p_shark 0.2136, mean 0.4636
# step 2600, loss 0.8501, min p_shark 0.2136, mean 0.4636
# step 2650, loss 0.8470, min p_shark 0.2190, mean 0.4620
# step 2650, loss 0.8470, min p_shark 0.2190, mean 0.4620
# step 2700, loss 0.8147, min p_shark 0.2889, mean 0.4628
# step 2700, loss 0.8147, min p_shark 0.2889, mean 0.4628
# step 2750, loss 0.7913, min p_shark 0.2696, mean 0.4757
# step 2800, loss 0.7982, min p_shark 0.2759, mean 0.4726
# step 2750, loss 0.7913, min p_shark 0.2696, mean 0.4757
# step 2800, loss 0.7982, min p_shark 0.2759, mean 0.4726
# step 2850, loss 0.7930, min p_shark 0.2908, mean 0.4719
# step 2900, loss 0.7795, min p_shark 0.3014, mean 0.4769
# step 2850, loss 0.7930, min p_shark 0.2908, mean 0.4719
# step 2900, loss 0.7795, min p_shark 0.3014, mean 0.4769
# step 2950, loss 0.7911, min p_shark 0.2934, mean 0.4714
# step 3000, loss 0.7739, min p_shark 0.2920, mean 0.4806
# step 2950, loss 0.7911, min p_shark 0.2934, mean 0.4714
# step 3000, loss 0.7739, min p_shark 0.2920, mean 0.4806
# step 3050, loss 0.7766, min p_shark 0.2698, mean 0.4818
# step 3050, loss 0.7766, min p_shark 0.2698, mean 0.4818
# step 3100, loss 0.7747, min p_shark 0.2899, mean 0.4799
# step 3150, loss 0.7635, min p_shark 0.3115, mean 0.4828
# step 3100, loss 0.7747, min p_shark 0.2899, mean 0.4799
# step 3150, loss 0.7635, min p_shark 0.3115, mean 0.4828
# step 3200, loss 0.7642, min p_shark 0.3025, mean 0.4840
# step 3200, loss 0.7642, min p_shark 0.3025, mean 0.4840
# step 3250, loss 0.7561, min p_shark 0.3313, mean 0.4852
# step 3250, loss 0.7561, min p_shark 0.3313, mean 0.4852
# step 3300, loss 0.7528, min p_shark 0.3038, mean 0.4911
# step 3300, loss 0.7528, min p_shark 0.3038, mean 0.4911
# step 3350, loss 0.7647, min p_shark 0.2847, mean 0.4865
# step 3350, loss 0.7647, min p_shark 0.2847, mean 0.4865
# step 3400, loss 0.7565, min p_shark 0.3079, mean 0.4899
# step 3400, loss 0.7565, min p_shark 0.3079, mean 0.4899
# step 3450, loss 0.7391, min p_shark 0.3110, mean 0.4956
# step 3450, loss 0.7391, min p_shark 0.3110, mean 0.4956
# step 3500, loss 0.7245, min p_shark 0.3459, mean 0.5024
# step 3500, loss 0.7245, min p_shark 0.3459, mean 0.5024
# step 3550, loss 0.7282, min p_shark 0.3294, mean 0.5003
# step 3550, loss 0.7282, min p_shark 0.3294, mean 0.5003
# step 3600, loss 0.7290, min p_shark 0.3396, mean 0.4986
# step 3650, loss 0.7465, min p_shark 0.2976, mean 0.4944
# step 3600, loss 0.7290, min p_shark 0.3396, mean 0.4986
# step 3650, loss 0.7465, min p_shark 0.2976, mean 0.4944
# step 3700, loss 0.7398, min p_shark 0.3322, mean 0.4928
# step 3700, loss 0.7398, min p_shark 0.3322, mean 0.4928
# step 3750, loss 0.7176, min p_shark 0.3312, mean 0.5054
# step 3750, loss 0.7176, min p_shark 0.3312, mean 0.5054
# step 3800, loss 0.7105, min p_shark 0.3529, mean 0.5056
# step 3800, loss 0.7105, min p_shark 0.3529, mean 0.5056
# step 3850, loss 0.7198, min p_shark 0.3296, mean 0.5034
# step 3850, loss 0.7198, min p_shark 0.3296, mean 0.5034
# step 3900, loss 0.7053, min p_shark 0.3324, mean 0.5108
# step 3900, loss 0.7053, min p_shark 0.3324, mean 0.5108
# step 3950, loss 0.7041, min p_shark 0.3691, mean 0.5077
# step 3999, loss 0.7051, min p_shark 0.3429, mean 0.5105
# step 3950, loss 0.7041, min p_shark 0.3691, mean 0.5077
# step 3999, loss 0.7051, min p_shark 0.3429, mean 0.5105

# %%
from torchvision.transforms.functional import to_pil_image



evaluate_strip(model, images, your_strip)

img_pil   = to_pil_image(images[0])
strip_pil = to_pil_image(your_strip)  # Tensor 3xHstripxW

img_pil.paste(strip_pil, (0, 0))  # wkleja pasek u góry
display(img_pil)
# Out:
# Probabilities assigned to: goldfish=10.35102%, shark=44.69903%.
# Probabilities assigned to: goldfish=9.99072%, shark=61.68548%.
# Probabilities assigned to: goldfish=0.46074%, shark=69.43678%.
# Probabilities assigned to: goldfish=0.23406%, shark=47.19869%.
# Probabilities assigned to: goldfish=30.68092%, shark=33.97757%.
# <PIL.Image.Image image mode=RGB size=100x100>
